# %%
print("Hello world")
# Out:
# Hello world

# %%
import os
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
#promt
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [("system", "당신은 천문학 전문가입니다."),
     ("user", "{input}")]
    )

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 천문학 전문가입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
prompt_text = prompt.format(input="지구의 자전주기는 얼마인가요?")

# %%
#llm 모델호출
from langchain_groq import ChatGroq

llm = ChatGroq(api_key=OPENAI_API_KEY, model_name="llama-3.3-70b-versatile")

# %%
response = llm.invoke(prompt_text)

# %%
response.content
# Out:
# '지구의 자전주기는 23시간 56분 4초입니다. 이 시간은 지구가 한 번 자전하는 데 걸리는 시간을 말합니다.'

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser
response = chain.invoke(input="지구의 자전주기는 얼마입니까?")

# %%
response
# Out:
# '지구의 자전주기는 약 23시간 56분 4.09초입니다. 이 시간은 지구가 자전축을 기준으로 한 번 회전하는 데 걸리는 시간을 나타내며, 이를 자전주기라고 합니다. 약 24시간으로 알려져 있지만 실제로는 약 3분 56초가 더 짧습니다.'
